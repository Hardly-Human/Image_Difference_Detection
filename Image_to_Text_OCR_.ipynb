# %% [markdown]
# <a href="https://colab.research.google.com/github/Hardly-Human/Image_Difference_Detection/blob/master/Image_to_Text_OCR_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !sudo add-apt-repository ppa:alex-p/tesseract-ocr
# !sudo apt install tesseract-ocr
# !sudo apt install libtesseract-dev
# !sudo pip install pytesseract

# %%
import requests

print ('Starting to Download!')

url = 'https://www.dropbox.com/s/5bdtfuwcs2z6gfv/Q3_Image_File_page-0001.jpg?dl=1'
r = requests.get(url)

filename = '2.jpg'

with open(filename, 'wb') as out_file:
    out_file.write(r.content)

print("Download complete!")
# Out:
# Starting to Download!
# Download complete!

# %%
import cv2
import numpy as np
import pytesseract
from PIL import Image


def get_string(img_path):
    img = cv2.imread(img_path)

    img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

    kernel = np.ones((1, 1), np.uint8)
    img = cv2.dilate(img, kernel, iterations=1)
    img = cv2.erode(img, kernel, iterations=1)

    cv2.imwrite("removed_noise.png", img)

    cv2.imwrite(img_path, img)

    result = pytesseract.image_to_string(Image.open(img_path))

    return result


print ('--- Start recognize text from image ---')
print (get_string('2.jpg'))

print ("------ Done -------")
# Out:
# --- Start recognize text from image ---
# 4
#
# STATE
#
# DECCANHERALD
# Wednesday
# June 10, 2020
#
#
#
# Aadhaar
# enrolment
# now under
#
# Jana Sevaka
#
# Almatti plant exceeds power
# generation target in 2019-20
#
# Experts junk govt denial
# of community spread
#
# Community, from Page 1
#
# The survey was carried out
# in 60 districts and 10 hard-
#
# of the government's failure
# to stem the outbreak.
#
# “The government should
# not feel embarrassed about
#
# ing capacity. Allsixwillbecome __ est-hit cities. it. It is fully expected. This
# BENGALURU, DHNS: Thestate 7 operational if the reservoir Asked why the govern- is how an epidemic grows.
# goemnmentwilnovorng | SIXUNits Combined produced 631.5 Mcesnamcieauidanter | ‘iene was sage On Loin. 1 connor ibe eomilerod as
#
# enrolment for Aadhaar,
# APL card and voters ID
#
# MUs as against target of 447 MUs
#
#
#
# ities start pumping/releasing
# 45,000 cusecs from the said
#
# munity transmission, John
# ...
